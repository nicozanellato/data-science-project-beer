# %% [markdown]
# # Recommendation system - Craft Beers
# ## Based on scraped data
#
# This jupyter notebook will show how to create a simple recommendation system based on data scraped from Untappd.com, an online app that allows you to discover and rate craft beers. In this notebook I will use 2 different recommendation systems. The first is based on a weighted average of ratings per each beer. The user will input the type of the beer they like the most and the system will return the top 10 beers with the highest rating for that type. Although the rating onn the app is already weighted based on the number of reviewers

# %%
import pandas as pd
import numpy as np
import time
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
beers = pd.read_csv('All Beers.csv', names = ['Beer ID','Brewery', 'Beer name', 'Beer Style', 'Beer Description', 'ABV', 'IBU', 'No Raters', 'Rating', 'Date Added'])

# %%
brew = pd.read_csv('Breweries.csv',names = ['ID','Brewery', 'Country', 'N Beers', 'No Raters', 'Rating', 'url', 'img_url', 'Brewery type', 'Address'])

# %%
brew = brew.drop(columns = ['ID'])

# %%
brew.head()
# Out:
#                      Brewery    Country  N Beers No Raters  Rating  \
# 0         Juguetes Perdidos   Argentina       38   1,119     3.961
# 1                     Manush  Argentina       30   1,089     3.614
# 2                   La Zorra  Argentina       26   1,008     3.549
# 3         Cervecería Antares  Argentina       69   9,740     3.442
# 4  Berlina Patagonia Brewery  Argentina       53   2,425     3.430
#
#                                                  url  \
# 0               https://untappd.com/JuguetesPerdidos
# 1                 https://untappd.com/w/manush/96147
# 2              https://untappd.com/w/la-zorra/186088
# 3               https://untappd.com/CerveceraAntares
# 4  https://untappd.com/w/berlina-patagonia-brewer...
#
#                                              img_url   Brewery type  \
# 0  https://untappd.akamaized.net/site/brewery_log...  Micro Brewery
# 1  https://untappd.akamaized.net/site/brewery_log...       Brew Pub
# 2  https://untappd.akamaized.net/site/brewery_log...  Micro Brewery
# 3  https://untappd.akamaized.net/site/brewery_log...  Micro Brewery
# 4  https://untappd.akamaized.net/site/brewery_log...  Micro Brewery
#
#                                            Address
# 0   Caseros, Buenos Aires, Buenos Aires Argentina
# 1    San Carlos de Bariloche, Río Negro Argentina
# 2                                       Argentina
# 3           Mar del Plata, Buenos Aires Argentina
# 4    San Carlos de Bariloche, Río Negro Argentina

# %%
# remove whitespaces at the beginning and the end of string 
beers['Brewery'] = beers['Brewery'].str.replace('^ ','')

# %%
beers['Brewery'] = beers['Brewery'].str.replace(' $','')

# %%
brew['Brewery'] = brew['Brewery'].str.replace('^ ','')
brew['Brewery'] = brew['Brewery'].str.replace(' $','')

# %%
beers1 = pd.merge(beers, brew, on = 'Brewery', how = 'left')

# %%
beers1.head(1)
# Out:
#    Beer ID            Brewery       Beer name      Beer Style  \
# 0  1649744  Juguetes Perdidos  Jamaica Dubbel  Belgian Dubbel
#
#                                     Beer Description   ABV    IBU No Raters_x  \
# 0  Clásica Dubbel de Abadía con adición de granos...   7     19          72
#
#   Rating_x   Date Added    Country  N Beers No Raters_y   Brewery type  \
# 0     4.1     07/17/16   Argentina       38     1,119    Micro Brewery
#
#                                            Address
# 0   Caseros, Buenos Aires, Buenos Aires Argentina

# %%
beers1 = beers1.drop(columns = ['Rating_y','url','img_url'])

# %%
beers['Rating'] = beers['Rating'].dropna()

# %%
beers['Rating'] = beers['Rating'].str.replace('N/A','0')

# %%
beers['Rating'] = beers['Rating'].str.replace('  N/A ','0')

# %%
beers['Rating'] = beers['Rating'].astype(float)

# %%
beers['No Raters'] = beers['No Raters'].str.replace(' Rating','0')

# %%
beers['No Raters'] = beers['No Raters'].str.replace(',','')

# %%
beers['No Raters'] = beers['No Raters'].astype(int)

# %%
beers['ABV'] = beers['ABV'].str.replace('N/A','')
beers['ABV'] = beers['ABV'].str.replace(' ','')
beers['ABV'] = beers['ABV'].dropna()
beers['ABV'] = pd.to_numeric(beers['ABV'])

# %%
beers = beers[beers['No Raters']>=20]

# %%
# calculate C first
C = beers['Rating'].mean()
print('The mean review across all restaurants is ', str(C)[0:5])
# Out:
# The mean review across all restaurants is  3.574

# %%
# caclulate m 
# What is the minimum number of review a restaurant need to have to be included in this chart
m = beers['No Raters'].quantile(0.50)
print('The minimum number of raters to be listed is',m)
# Out:
# The minimum number of reviews required to be listed is 203.0

# %%
# get restaurants that have at leat m reviews
SR_data = beers.copy().loc[beers['No Raters'] >= m]
print(str(SR_data.shape[0]) + ' beers can be included in the chart')
# Out:
# 16957 beers can be included in the chart

# %%
# create a function that calculate the weighted review for each beer
def weighted_review(x, m=m, C=C):
    # v is the number of reveiws of a particular restaurant
    v = x['No Raters']
    # R is the average rating 
    R = x['Rating']
    # weighted rating
    WR = (v/(v+m) * R) + (m/(m+v) * C)
    # return weighted rating
    return WR

# %%
# create a new column of dataframe called 'score' where to store this value 
SR_data['weighted_score'] = SR_data.apply(weighted_review, axis=1)

# %%
SR_data.head()
# Out:
#    Beer ID               Brewery       Beer name                 Beer Style  \
# 0  1028555             La Zorra              IPA             IPA - American
# 0    12382   Cervecería Antares       Barleywine      Barleywine - American
# 1    12375   Cervecería Antares           Scotch     Scotch Ale / Wee Heavy
# 2    12372   Cervecería Antares           Kölsch                     Kölsch
# 3    12383   Cervecería Antares   Imperial Stout  Stout - Imperial / Double
#
#                                     Beer Description   ABV    IBU  No Raters  \
# 0                                          Read Less   6.8   45          219
# 0  Nuestra cerveza de mayor graduación alcohólica...  10.0   50         1287
# 1                                          Read Less   6.0   18         1231
# 2                                          Read Less   5.0   22         1236
# 3  Catalina la Grande amaba las emociones fuertes...   8.5   36         1183
#
#    Rating   Date Added  weighted_score
# 0    3.70    03/29/15         3.639593
# 0    3.55    12/02/10         3.553328
# 1    3.33    12/02/10         3.364601
# 2    3.25    12/02/10         3.295767
# 3    3.59    12/02/10         3.587719

# %%
# filter beers based on type and ABV and then tell me the best 15 according to my score

# input type you want to select 
b_type = str(input('Insert beer type or all types: '))
# input price range 
abv = str(input('Insert alcohol percentage : '))
abv = float(abv)
# if the price range is 'all'
if b_type == 'all':
    # only filter the beer 
    beer_data = SR_data[(SR_data['ABV'] >= abv)&(SR_data['ABV'] <= abv+1)]
else:
    # otherwise filter the city and price range
    beer_data = SR_data.loc[(SR_data['Beer Style'] == b_type) & (SR_data['ABV'] >= abv) &(SR_data['ABV'] <= abv+1),:]

# sort restaurant by score 
beer_data = beer_data.sort_values('weighted_score', ascending=False)

# show top 10 rated beers in that city and price range 
beer_data[['Brewery','Beer name','Beer Style','Beer Description','ABV','IBU','No Raters','Rating','weighted_score']].head(10)
# Out:
# Insert beer type or all types: Stout - Milk / Sweet
# Insert alcohol percentage : 5
#                               Brewery              Beer name  \
# 10        Tree House Brewing Company    That's What She Said
# 5                   BKS Artisan Ales        Holstein (Maple)
# 0                       Thirsty Crow      Vanilla Milk Stout
# 2          Microbrasserie Vox Populi   Vox Stout (Milkshake)
# 12                    Wiper And True   Hard Shake Milk Stout
# 0    Brewlok Craft & Classic Brewery               Baba Yaga
# 8                8 Wired Brewing Co.              Flat White
# 1                         Ras L'Bock             Señor Cacao
# 0                     Wiper And True        Milk Shake Stout
# 3                         La Patrona             Sta. Tomasa
#
#               Beer Style                                   Beer Description  \
# 10  Stout - Milk / Sweet  A sneakily complex beer, "TWSS" exhibits flavo...
# 5   Stout - Milk / Sweet                                          Read Less
# 0   Stout - Milk / Sweet  Arguably Wagga’s most famous export since the ...
# 2   Stout - Milk / Sweet  Stout au lactose, riche, crémeuse et vanillée ...
# 12  Stout - Milk / Sweet                                          Read Less
# 0   Stout - Milk / Sweet  Milk stout with the addition of large portions...
# 8   Stout - Milk / Sweet  A rather traditional milk stout, taken up a no...
# 1   Stout - Milk / Sweet  Deux péchés mignons rasemblés pour assouvir vo...
# 0   Stout - Milk / Sweet  A milk stout uses sugar made from cows milk to...
# 3   Stout - Milk / Sweet                                          Read Less
#
#      ABV     IBU  No Raters  Rating  weighted_score
# 10  5.60    28        16725    4.16        4.152978
# 5   5.64   N/A          328    4.34        4.047322
# 0   5.20   N/A         1202    4.08        4.006952
# 2   5.50    25         1658    4.01        3.962487
# 12  6.00    18          945    4.02        3.941209
# 0   6.00   N/A         1198    3.96        3.904131
# 8   5.50   N/A         3805    3.92        3.902497
# 1   6.00    22          663    4.00        3.900240
# 0   5.60    15         8287    3.89        3.882454
# 3   6.00    30          279    4.09        3.872859

# %%
# make a description column by adding the couisine style and the price range. 

# make cuisine style and price range columns strings
cols = ['Beer Style', 'ABV']
for col in cols: 
    beers[col] = beers[col].astype(str)

beers['description'] = beers['Beer Style'] + ' ' + beers['ABV']

# %%
beers = beers.reset_index()
beers = beers.drop(columns=['index'])

# %%
beers.head(7)
# Out:
#    Beer ID              Brewery                          Beer name  \
# 0  1649744   Juguetes Perdidos                      Jamaica Dubbel
# 1  1967868   Juguetes Perdidos                     Saison Maracuyá
# 2  1809101   Juguetes Perdidos   Imperial Saison Chardonnay Barrel
# 3  1277658   Juguetes Perdidos     Good Bye Lenin! - Baltic Porter
# 4  1227273   Juguetes Perdidos            Hop de Lis - Belgian IPA
# 5  1677114   Juguetes Perdidos                       Kill Your IPA
# 6  2138002   Juguetes Perdidos         Monster Ale - Del 1 al 1000
#
#                 Beer Style                                   Beer Description  \
# 0           Belgian Dubbel  Clásica Dubbel de Abadía con adición de granos...
# 1   Saison / Farmhouse Ale         Maracuyá / Passion Fruit Infused Read Less
# 2   Saison / Farmhouse Ale  Spiced Saison, High Gravity, aged in white win...
# 3          Porter - Baltic  Chocolate, café y un tenor alcohólico importan...
# 4            IPA - Belgian  American IPA fermentada con levadura Belga Rea...
# 5  IPA - Imperial / Double  Imperial IPA de Sir Hopper exquisitamente blen...
# 6  IPA - Imperial / Double  Cerveza para celebrar los 1000 socios de la As...
#
#     ABV      IBU  No Raters  Rating   Date Added                   description
# 0   7.0     19           72    4.10    07/17/16             Belgian Dubbel 7.0
# 1   7.0     19           57    3.93    02/25/17     Saison / Farmhouse Ale 7.0
# 2  11.7     25           60    3.76    11/05/16    Saison / Farmhouse Ale 11.7
# 3   9.0     25           52    3.99    10/17/15            Porter - Baltic 9.0
# 4   6.6     66           47    4.25    09/06/15              IPA - Belgian 6.6
# 5   9.5     90           52    4.09    08/05/16    IPA - Imperial / Double 9.5
# 6  12.3   1000           50    3.61    06/10/17   IPA - Imperial / Double 12.3

# %%
# reduce dataset
m = beers['No Raters'].quantile(0.95)
CR_data = beers.copy().loc[beers['No Raters'] >= m]
#CR_data = beers.copy()
#CR_data = CR_data[CR_data['No Raters']]
CR_data = CR_data.reset_index(drop=True)

# create matrix with descriptions
tfidf = TfidfVectorizer(stop_words='english')
CR_data['description']= CR_data['description'].fillna('')
tfidf_matrix = tfidf.fit_transform(CR_data['description'])

# calculate similarity 
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
def get_recommendations(name, b_type = 'all', cosine_sim=cosine_sim):
    b_type = b_type
    
    # reset indeces
    indices = pd.Series(CR_data.index, index=CR_data['Beer name']).drop_duplicates()
    
    # Get the index of the movie that matches the title
    idx = indices[name]

    # Get the pairwsie similarity scores of all restaurant with that restaurant
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the restaurants based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Get the restaurants indices
    res_indices = [i[0] for i in sim_scores]
    
    # get name, city and description of restaurant 
    sim_res = CR_data[['Beer name','Beer Style','Brewery','description']].iloc[res_indices]
    
    # if city is set to all, 
    if b_type != 'all':
        # only show the ones from that city 
        r = sim_res.loc[sim_res['Beer Style'] == b_type, :].head(10)
    else:
        # else show all 
        r = CR_data[['Beer name','Brewery','description']].iloc[res_indices].head(10)

    # Return the top 10 most similar restaurants
    return r

# %%
# ger recommendations for beers similar to 
name = str(input('Insert the name of the beer: '))
b_type = str(input('Insert the beer style: '))

print('If you enjoyed ', name, 'and', b_type, 'kind of beers you could try:' )
get_recommendations(name, b_type=b_type)
# Out:
# Insert the name of the beer: XPA
# Insert the beer style: all
# If you enjoyed  XPA and all kind of beers you could try:
#                                 Beer name  \
# 16                                    XPA
# 899            961 Beer Lebanese Pale Ale
# 1134         Lorita Passionfruit Pale Ale
# 1439                        Shape Shifter
# 517                         New World IPA
# 537                         Ramberget IPA
# 787                             Chieftain
# 822               O'Hara's Irish Pale Ale
# 876   Hitachino Nest Japanese Classic Ale
# 961                      Bird of Prey IPA
#
#                                           Brewery  \
# 16                        Balter Brewing Company
# 899                          Gravity Brewing Sal
# 1134                           Amundsen Bryggeri
# 1439                             Dugges Bryggeri
# 517                                Northern Monk
# 537                               Buxton Brewery
# 787                      Franciscan Well Brewery
# 822    O'Hara's Brewery (Carlow Brewing Company)
# 876                               Kiuchi Brewery
# 961                                   Het Uiltje
#
#                        description
# 16    Pale Ale - International 5.0
# 899   Pale Ale - International 6.3
# 1134  Pale Ale - International 4.7
# 1439  Pale Ale - International 6.0
# 517        IPA - International 6.2
# 537        IPA - International 7.2
# 787        IPA - International 5.5
# 822        IPA - International 5.2
# 876        IPA - International 7.0
# 961        IPA - International 5.8
